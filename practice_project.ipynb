# %% [markdown]
# <a href="https://colab.research.google.com/github/kounainaftab/45-exercises/blob/main/practice_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***`My first practice`***

# %% [markdown]
# Hello world

# %%
print("hello world")
# Out:
# hello world

# %%
print("my name is kounain")
# Out:
# my name is kounain

# %% [markdown]
# My second program using input and print

# %%
color = input("Enter a color:")
noun = input("Enter a noun:")
activity = input("Enter an activity:")
print("Roses are" + color)
print(noun + "are blue")
print("we love" + activity+ "you should do!")
# Out:
# Enter a color:red
# Enter a noun:park
# Enter an activity:reading
# Roses arered
# parkare blue
# we lovereadingyou should do!
